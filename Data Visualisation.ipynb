# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('C:/Users/sai kiran/Downloads/loan_final313 - Copy.csv')
data.head()
# Out:
#         id  year     issue_d  final_d  emp_length_int home_ownership  \
# 0  1077501  2011  01/12/2011  1012015            10.0           RENT
# 1  1077430  2011  01/12/2011  1042013             0.5           RENT
# 2  1077175  2011  01/12/2011  1062014            10.0           RENT
# 3  1076863  2011  01/12/2011  1012015            10.0           RENT
# 4  1075358  2011  01/12/2011  1012016             1.0           RENT
#
#    home_ownership_cat income_category  annual_inc  income_cat    ...     \
# 0                   1             Low       24000           1    ...
# 1                   1             Low       30000           1    ...
# 2                   1             Low       12252           1    ...
# 3                   1             Low       49200           1    ...
# 4                   1             Low       80000           1    ...
#
#    loan_condition_cat interest_rate  grade grade_cat    dti   total_pymnt  \
# ...

# %% [markdown]
# ### will check for null values
# ### The data doesn't contain any null values

# %%
a=data.columns
for b in a:
    print(b+' - '+str(data[b].isnull().sum()))
# Out:
# id - 0
# year - 0
# issue_d - 0
# final_d - 0
# emp_length_int - 0
# home_ownership - 0
# home_ownership_cat - 0
# income_category - 0
# annual_inc - 0
# income_cat - 0
# loan_amount - 0
# term - 0
# term_cat - 0
# application_type - 0
# application_type_cat - 0
# purpose - 0
# purpose_cat - 0
# interest_payments - 0
# interest_payment_cat - 0
# loan_condition - 0
# loan_condition_cat - 0
# interest_rate - 0
# grade - 0
# grade_cat - 0
# dti - 0
# total_pymnt - 0
# total_rec_prncp - 0
# recoveries - 0
# installment - 0
# region - 0

# %%
#will remove some unnecessary features such as id which doesn't contribute to actual end task

# %%
data.drop('id',axis=1,inplace=True)
data.head()
# Out:
#    year     issue_d  final_d  emp_length_int home_ownership  \
# 0  2011  01/12/2011  1012015            10.0           RENT
# 1  2011  01/12/2011  1042013             0.5           RENT
# 2  2011  01/12/2011  1062014            10.0           RENT
# 3  2011  01/12/2011  1012015            10.0           RENT
# 4  2011  01/12/2011  1012016             1.0           RENT
#
#    home_ownership_cat income_category  annual_inc  income_cat  loan_amount  \
# 0                   1             Low       24000           1         5000
# 1                   1             Low       30000           1         2500
# 2                   1             Low       12252           1         2400
# 3                   1             Low       49200           1        10000
# 4                   1             Low       80000           1         3000
#
#      ...    loan_condition_cat  interest_rate grade  grade_cat    dti  \
# 0    ...                     0          10.65     B          2  27.65
# ...

# %%
sns.factorplot('loan_condition',hue='home_ownership',data=data,kind='count')

# %%
### From the above visualisation, it is quite clear that, ['other','None','Any'] can be removed from 'home_ownership' attribute

# %%
sns.factorplot('loan_condition',hue='income_cat',data=data,kind='count')

# %%
sns.factorplot('loan_condition',hue='grade_cat',data=data,kind='count')

# %%
sns.factorplot('loan_condition',hue='term_cat',data=data,kind='count')

# %%
sns.factorplot('loan_condition',hue='application_type_cat',data=data,kind='count')

# %%
sns.factorplot('loan_condition',hue='purpose_cat',data=data,kind='count')

# %%
sns.factorplot('loan_condition',hue='interest_payment_cat',data=data,kind='count')

# %%
sns.factorplot('loan_condition',hue='loan_condition_cat',data=data,kind='count')

# %%
sns.factorplot('loan_condition',hue='region',data=data,kind='count')

# %%
sns.factorplot('loan_condition',hue='year',data=data,kind='count')

# %%
data['loan_amount'].hist(bins=10)

# %%
data['emp_length_int'].hist(bins=5)

# %%
data['interest_rate'].hist(bins=90)

# %%
data['interest_rate'].hist(bins=5)

# %%
data['dti'].hist(bins=5)

# %%
data['total_pymnt'].hist(bins=10)

# %%
data['total_rec_prncp'].hist(bins=20)

# %%
data['recoveries'].hist(bins=20)

# %%
data['installment'].hist(bins=5)
